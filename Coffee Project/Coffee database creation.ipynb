# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd
import time
import re
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float
Base = declarative_base()
import pymysql
pymysql.install_as_MySQLdb()
import numpy as np

# %%
# Set path 
import sys
sys.path.append('../')

# Config variables
from config import remote_db_endpoint, remote_db_port
from config import remote_gwsis_dbname, remote_gwsis_dbuser, remote_gwsis_dbpwd
from config import local_gwsis_dbname, local_gwsis_dbuser, local_gwsis_dbpwd

# %%
# local Connection Backup 
lengine = create_engine(f"mysql://{local_gwsis_dbuser}:{local_gwsis_dbpwd}@localhost:3306/{local_gwsis_dbname}")

# AWS Database Connection
#engine = create_engine(f"mysql://{remote_gwsis_dbuser}:{remote_gwsis_dbpwd}@{remote_db_endpoint}:{remote_db_port}/{remote_gwsis_dbname}")

# %%
# Create a local database engine connection
lconn = lengine.connect()

# Create a remote database engine connection
#conn = engine.connect()

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#create a list to hold coffee types
coffee_types = []

# %%
#assign url
url = "https://www.drippedcoffee.com/best-coffee-beans/"

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
html = soup.html

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Best Coffee Beans (in the World) to Buy in 2019 - Our Top Picks
#   </title>
#   <style type="text/css">
#    .tve_more_tag {visibility: hidden; height: 1px!important;}
#   </style>
#   <!-- Social Warfare v3.5.4 https://warfareplugins.com -->
#   <style>
#    @font-face {font-family: "sw-icon-font";src:url("https://www.drippedcoffee.com/wp-content/plugins/social-warfare/assets/fonts/sw-icon-font.eot?ver=3.5.4");src:url("https://www.drippedcoffee.com/wp-content/plugins/social-warfare/assets/fonts/sw-icon-font.eot?ver=3.5.4#iefix") format("embedded-opentype"),url("https://www.drippedcoffee.com/wp-content/plugins/social-warfare/assets/fonts/sw-icon-font.woff?ver=3.5.4") format("woff"),
# ...

# %%
c_list = []
#Grab coffee Types
coffee_type_list = soup.find_all('h3')


for c in coffee_type_list:
    grr = c.find_all('a')
    
    for g in grr:
        
        dagnabit = g.find_all('strong')
        
        for d in dagnabit:
            
            strong = d.find_all('strong')
            
            for s in strong:            
                print(s.text)

df = pd.DataFrame(s.text)
                
df                           
                                  
                                  
#coffee_type_list_items = coffee_type_list.find('strong').text
#coffee_type_list_items
# Out:
# LifeBoost Coffee
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-25db9ddbb84c> in <module>
#      18                 print(s.text)
#      19
# ---> 20                 df = pd.DataFrame(s.text)
#      21
#      22 df
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466                                    dtype=values.dtype, copy=False)
#     467             else:
# --> 468                 raise ValueError('DataFrame constructor not properly called!')
#     469
#     470         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
#import into a DB
# Out:
# 'LifeBoost Coffee'

# %%
#coffee origin list 

origin = ['origin']

# %%
for o in origin:

# %%
#Grab coffee Origins

coffee_origin_list = soup.find_all('p')

for co in coffee_origin_list: 
    col1 = co.find_all('span', attrs={'data-css': ''})
    
    for c in col1:
        col2 = c.find_all('span')
        print(col2)
# Out:
# [<span class="entry-author-name" itemprop="name">Dennies John</span>]
# []
# []
# []
# []
# []
# [<span class="ttfm1">Arabica</span>]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [<span class="ttfm1" data-css="tve-u-1621a2c1ce8" style="color: rgb(67, 67, 67);">Origin: Jamaica</span>]
# []
# [<span class="ttfm1" data-css="tve-u-1621a2c1cf4" style="color: rgb(67, 67, 67);">Roast: Medium</span>]
# []
# []
# []
# []
# []
# []
# []
# [<span class="ttfm1">Origin: Kenya</span>]
# []
# [<span class="ttfm1">Roast: Medium</span>]
# []
# []
# []
# [<span class="ttfm1">Origin: Tanzania</span>]
# []
# [<span class="ttfm1">Roast: Medium</span>]
# []
# []
# []
# []
# [<span class="ttfm1">Origin: Indonesia</span>]
# []
# [<span class="ttfm1">Roast: Medium</span>]
# []
# []
# []
# [<span class="ttfm1">Origin: Indonesia</span>]
# []
# [<span class="ttfm1">Roast: Medium</span>]
# []
# []
# []
# ...
